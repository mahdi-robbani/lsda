# %% [markdown]
# # Small CNN for traffic sign recognition as template for  assignment
# ## Christian Igel, 2020
#
# This notebook provides a template for a small CNN for the German Traffic Sign Recognition Benchmark. The data is described in:
#
# Johannes Stallkamp, Marc Schlipsing, Jan Salmen, and Christian Igel. Man vs. Computer: Benchmarking Machine Learning Algorithms for Traffic Sign Recognition. *Neural Networks* **32**, pp. 323-332, 2012
#
# This notebook is a template, without modification the model does not even come close to the state-of-the-art.

# %%
# Install, restart runtime, run all
# !pip install comet_ml

# %%
## For reproducibility
from comet_ml import Experiment

seed_value = 420420
experiment = Experiment(api_key="zmx2tdNM2D3GnUg4jtTLpQ2Vy",
                        project_name="HW2_Version0", workspace="lallakala")
Experiment.add_tag(experiment, "Original")

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt 
import numpy as np
import pathlib
import os

print("TensorFlow version:", tf.__version__)

AUTOTUNE = tf.data.experimental.AUTOTUNE
# Out:
# TensorFlow version: 2.2.0-rc4

# %% [markdown]
# # FILE REPRODUCIBILITY

# %%
experiment.log_other("random seed", seed_value)

# Set the seed value for all the frameworks
os.environ['PYTHONHASHSEED']=str(seed_value)

import random
random.seed(seed_value)

np.random.seed(seed_value)

tf.random.set_seed(seed_value)

# set seed values                                   # add that if use dropout
# model.add(Dropout(0.25, seed=seed_value))

# Configure a new global `tensorflow` session
#from keras import backend as K
#session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
#sess = tf.compat.v1.Session()(graph=tf.compat.v1.get_default_graph(), config=session_conf)
#K.set_session(sess)

# %% [markdown]
# Download the data:

# %%
data_root="."
tf.keras.utils.get_file("GTSRB.zip",
                        "https://sid.erda.dk/share_redirect/EB0rrpZwuI",
                        cache_dir=data_root,
                        extract=True)
# Out:
# Downloading data from https://sid.erda.dk/share_redirect/EB0rrpZwuI
# 290897920/290897892 [==============================] - 4s 0us/step
# './datasets/GTSRB.zip'

# %% [markdown]
# The images are stored in subdirectories. The names of the subdirectories encode the class labels.

# %%
# Determine the number of training and test images
n_train = len(list(pathlib.Path(data_root).glob("datasets/GTSRB/train/*/*")))
n_test = len(list(pathlib.Path(data_root).glob("datasets/GTSRB/test/*/*")))

print("Number of training images:", n_train)
print("Number of test images:" ,n_test)
# Out:
# Number of training images: 39209
# Number of test images: 12630

# %% [markdown]
# Some basic constants:

# %%
no_classes = 43  # There are 43 different signs
no_channels = 3  # We are dealing with color images

# All images are initially resized to img_height x img_width
img_height  = 32  
img_width   = 32
# During training and testing the  images are cropped to img_height_crop x img_width_crop
img_height_crop = 28  
img_width_crop  = 28

batch_size = 128
steps_per_epoch = n_train // batch_size  # How many batches are there in each epoch?

# %% [markdown]
# Helper function for extracting the label information from the paths to the images and loading and preprocessing the images:

# %%
# Extract the label from the file path
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return tf.strings.to_number(parts[-2], tf.int32)

# Load image, convert it to floats, and resize it
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=no_channels)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # Resize the image to the desired size.
  return tf.image.resize(img, [img_width, img_height])

# Given the path and filename of an image, create the label and the input image
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# Create data sets based on the files:

# %%
# Tell dataset the lists of files containing the trainig and test images, respectively
list_ds_train = tf.data.Dataset.list_files(data_root + "/datasets/GTSRB/train/*/*")
list_ds_test  = tf.data.Dataset.list_files(data_root + "/datasets/GTSRB/test/*/*", shuffle=False)  # Fixed order for test time augemantation 

# Tell dataset how to extract images and labels
labeled_ds_train = list_ds_train.map(process_path, num_parallel_calls=AUTOTUNE)
labeled_ds_test = list_ds_test.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Functions for data preprocessing/augmentation:

# %%
# Used for training data augmentation
def augment(image, label):
    image = tf.image.random_crop(image, [img_height_crop, img_width_crop, no_channels])
    image = tf.case([(tf.equal(label, 11), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 12), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 13), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 17), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 18), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 26), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 30), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 35), lambda: tf.image.random_flip_left_right(image))], default = lambda: image)
    image = tf.image.random_brightness(image, max_delta=0.1) # Random brightness
    image = tf.clip_by_value(image, 0., 1.)
    return image, label

# Used for testing/evaluation
def crop_center(image, label):
  image = tf.image.resize_with_crop_or_pad(image, img_height_crop, img_width_crop)
  return image, label

# Could be used for test time augementation
def crop_random(image, label):
  image = tf.image.random_crop(image, [img_height_crop, img_width_crop, no_channels])
  return image, label

# %% [markdown]
# We prepare the data for training and testing differently. For example, for training we use data augmentation.

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  # `.cache(filename)` is used to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):  # Is the chache argument a string?
      ds = ds.cache(cache)  # If yes, we cache to a file
    else:
      ds = ds.cache()  
  # We shuffle the data after the caching
  ds = ds.shuffle(buffer_size=shuffle_buffer_size, reshuffle_each_iteration=True)
  # Repeat forever
  ds = ds.repeat()
  # Do data augmentation
  ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
  # Partition in batches
  ds = ds.batch(batch_size)
  # Fetch batches in the background while the model training
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

def prepare_for_evaluation(ds, shuffle_buffer_size=1000):
  # For normal evaluation, we look at the center of the image
  ds = ds.map(crop_center, num_parallel_calls=AUTOTUNE)
  # Partition in batches
  ds = ds.batch(batch_size)
  # Fetch batches in the background while the model training
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

def prepare_for_augmented_evaluation(ds):
  ds = ds.map(crop_random, num_parallel_calls=AUTOTUNE)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %% [markdown]
# Let's have a look at a random batch of images:

# %%
# Helper function for displaying images
def show_batch(image_batch, label_batch, nrows=6, ncols=6):
  plt.figure(figsize=(10,10))
  for n in range(nrows*ncols):
      ax = plt.subplot(nrows, ncols, n+1)
      if no_channels == 3:
        plt.imshow(image_batch[n])
      else:
        plt.imshow(image_batch[n].reshape([img_height_crop, img_width_crop]))
      plt.title('class:' + str(label_batch[n]))
      plt.axis('off')
# Make training dataset to retrieve some images
train_ds = prepare_for_training(labeled_ds_train)

# Get a batch of images and labels
image_batch, label_batch = next(iter(train_ds))

# Visualize images and labels
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# Define a neural network model:

# %%
sd_init = 0.01  # Standard deviation and offset for initializing bias parameters in hidden layers

# set seed values 
# model.add(Dropout(0.25, seed=seed_value))

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), activation=None,  
                           input_shape=(img_width_crop, img_height_crop, no_channels),
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_init, stddev=sd_init)),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Conv2D(64, (5, 5), activation=None, 
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_init, stddev=sd_init)),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(no_classes, activation='softmax')])
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 32)        2432
# _________________________________________________________________
# elu (ELU)                    (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# elu_1 (ELU)                  (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 43)                44075
# =================================================================
# Total params: 97,771
# Trainable params: 97,771
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Define optimizer and compile the model:

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001, epsilon=0.1)
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])  # sparse categorical crossentropy does the one hot encoding for us under the hood

# %% [markdown]
# Do the learning:

# %%
# Train the model
import time
start = time.time()

history = model.fit(train_ds, epochs=500, steps_per_epoch=steps_per_epoch)

print("Training took", (time.time() - start)/60, "minutes.")
# Out:
# COMET INFO: Ignoring automatic log_parameter('verbose') because 'keras:verbose' is in COMET_LOGGING_PARAMETERS_IGNORE
# Epoch 1/500
# 306/306 [==============================] - 20s 66ms/step - loss: 3.5762 - accuracy: 0.0612
# Epoch 2/500
# 306/306 [==============================] - 6s 19ms/step - loss: 3.4061 - accuracy: 0.1268
# Epoch 3/500
# 306/306 [==============================] - 6s 20ms/step - loss: 3.1521 - accuracy: 0.2264
# Epoch 4/500
# 306/306 [==============================] - 6s 19ms/step - loss: 2.6977 - accuracy: 0.3135
# Epoch 5/500
# 306/306 [==============================] - 6s 20ms/step - loss: 2.2587 - accuracy: 0.3980
# Epoch 6/500
# 306/306 [==============================] - 6s 19ms/step - loss: 1.9187 - accuracy: 0.4762
# Epoch 7/500
# 306/306 [==============================] - 6s 18ms/step - loss: 1.6638 - accuracy: 0.5428
# Epoch 8/500
# 306/306 [==============================] - 5s 18ms/step - loss: 1.4630 - accuracy: 0.6007
# Epoch 9/500
# 306/306 [==============================] - 6s 19ms/step - loss: 1.3117 - accuracy: 0.6433
# Epoch 10/500
# 306/306 [==============================] - 6s 19ms/step - loss: 1.1719 - accuracy: 0.6870
# Epoch 11/500
# 306/306 [==============================] - 6s 18ms/step - loss: 1.0800 - accuracy: 0.7134
# Epoch 12/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.9888 - accuracy: 0.7376
# Epoch 13/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.9129 - accuracy: 0.7592
# Epoch 14/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.8453 - accuracy: 0.7798
# Epoch 15/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.7893 - accuracy: 0.7960
# Epoch 16/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.7349 - accuracy: 0.8117
# Epoch 17/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.6937 - accuracy: 0.8241
# Epoch 18/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.6433 - accuracy: 0.8370
# Epoch 19/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.6128 - accuracy: 0.8466
# Epoch 20/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.5802 - accuracy: 0.8558
# Epoch 21/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.5547 - accuracy: 0.8623
# Epoch 22/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.5197 - accuracy: 0.8718
# Epoch 23/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.5009 - accuracy: 0.8764
# Epoch 24/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.4776 - accuracy: 0.8812
# Epoch 25/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.4569 - accuracy: 0.8894
# Epoch 26/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.4311 - accuracy: 0.8944
# Epoch 27/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.4167 - accuracy: 0.8969
# Epoch 28/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.3995 - accuracy: 0.9028
# Epoch 29/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.3822 - accuracy: 0.9080
# Epoch 30/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.3671 - accuracy: 0.9096
# Epoch 31/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.3601 - accuracy: 0.9137
# Epoch 32/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.3514 - accuracy: 0.9162
# Epoch 33/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.3286 - accuracy: 0.9217
# Epoch 34/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.3164 - accuracy: 0.9262
# Epoch 35/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.3140 - accuracy: 0.9258
# Epoch 36/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2962 - accuracy: 0.9297
# Epoch 37/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.2936 - accuracy: 0.9306
# Epoch 38/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.2878 - accuracy: 0.9327
# Epoch 39/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2813 - accuracy: 0.9333
# Epoch 40/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2733 - accuracy: 0.9372
# Epoch 41/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2638 - accuracy: 0.9384
# Epoch 42/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2609 - accuracy: 0.9386
# Epoch 43/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.2490 - accuracy: 0.9405
# Epoch 44/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2487 - accuracy: 0.9417
# Epoch 45/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.2330 - accuracy: 0.9455
# Epoch 46/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2271 - accuracy: 0.9472
# Epoch 47/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.2366 - accuracy: 0.9450
# Epoch 48/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.2189 - accuracy: 0.9489
# Epoch 49/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.2149 - accuracy: 0.9492
# Epoch 50/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.2177 - accuracy: 0.9485
# Epoch 51/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.2099 - accuracy: 0.9507
# Epoch 52/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.2050 - accuracy: 0.9525
# Epoch 53/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1984 - accuracy: 0.9546
# Epoch 54/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.2026 - accuracy: 0.9532
# Epoch 55/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1900 - accuracy: 0.9555
# Epoch 56/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1925 - accuracy: 0.9559
# Epoch 57/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1873 - accuracy: 0.9561
# Epoch 58/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1834 - accuracy: 0.9580
# Epoch 59/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1775 - accuracy: 0.9581
# Epoch 60/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1760 - accuracy: 0.9588
# Epoch 61/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1744 - accuracy: 0.9602
# Epoch 62/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1642 - accuracy: 0.9615
# Epoch 63/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1647 - accuracy: 0.9624
# Epoch 64/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1637 - accuracy: 0.9631
# Epoch 65/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1636 - accuracy: 0.9631
# Epoch 66/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1594 - accuracy: 0.9635
# Epoch 67/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1590 - accuracy: 0.9648
# Epoch 68/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.1550 - accuracy: 0.9643
# Epoch 69/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1539 - accuracy: 0.9641
# Epoch 70/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1482 - accuracy: 0.9662
# Epoch 71/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1490 - accuracy: 0.9663
# Epoch 72/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1476 - accuracy: 0.9664
# Epoch 73/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1466 - accuracy: 0.9665
# Epoch 74/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1415 - accuracy: 0.9681
# Epoch 75/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1409 - accuracy: 0.9680
# Epoch 76/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1405 - accuracy: 0.9676
# Epoch 77/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1399 - accuracy: 0.9681
# Epoch 78/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1368 - accuracy: 0.9678
# Epoch 79/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1340 - accuracy: 0.9686
# Epoch 80/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1309 - accuracy: 0.9700
# Epoch 81/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1306 - accuracy: 0.9693
# Epoch 82/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1273 - accuracy: 0.9705
# Epoch 83/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1246 - accuracy: 0.9717
# Epoch 84/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1218 - accuracy: 0.9714
# Epoch 85/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1217 - accuracy: 0.9708
# Epoch 86/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1244 - accuracy: 0.9710
# Epoch 87/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1220 - accuracy: 0.9722
# Epoch 88/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1230 - accuracy: 0.9716
# Epoch 89/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1170 - accuracy: 0.9738
# Epoch 90/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1178 - accuracy: 0.9728
# Epoch 91/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1166 - accuracy: 0.9741
# Epoch 92/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1174 - accuracy: 0.9746
# Epoch 93/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1115 - accuracy: 0.9731
# Epoch 94/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1048 - accuracy: 0.9768
# Epoch 95/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1132 - accuracy: 0.9740
# Epoch 96/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1127 - accuracy: 0.9743
# Epoch 97/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.1053 - accuracy: 0.9768
# Epoch 98/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1061 - accuracy: 0.9757
# Epoch 99/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1049 - accuracy: 0.9756
# Epoch 100/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1011 - accuracy: 0.9775
# Epoch 101/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.1055 - accuracy: 0.9767
# Epoch 102/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1052 - accuracy: 0.9760
# Epoch 103/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1039 - accuracy: 0.9762
# Epoch 104/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.1029 - accuracy: 0.9769
# Epoch 105/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0968 - accuracy: 0.9772
# Epoch 106/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.1017 - accuracy: 0.9769
# Epoch 107/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0981 - accuracy: 0.9774
# Epoch 108/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0947 - accuracy: 0.9786
# Epoch 109/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0952 - accuracy: 0.9777
# Epoch 110/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0940 - accuracy: 0.9785
# Epoch 111/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0977 - accuracy: 0.9773
# Epoch 112/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0937 - accuracy: 0.9789
# Epoch 113/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0916 - accuracy: 0.9787
# Epoch 114/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0880 - accuracy: 0.9795
# Epoch 115/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0919 - accuracy: 0.9798
# Epoch 116/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0901 - accuracy: 0.9787
# Epoch 117/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0900 - accuracy: 0.9799
# Epoch 118/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0871 - accuracy: 0.9799
# Epoch 119/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0881 - accuracy: 0.9806
# Epoch 120/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0881 - accuracy: 0.9799
# Epoch 121/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0854 - accuracy: 0.9803
# Epoch 122/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0827 - accuracy: 0.9821
# Epoch 123/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0878 - accuracy: 0.9798
# Epoch 124/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0845 - accuracy: 0.9807
# Epoch 125/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0852 - accuracy: 0.9808
# Epoch 126/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0799 - accuracy: 0.9813
# Epoch 127/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0806 - accuracy: 0.9818
# Epoch 128/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0772 - accuracy: 0.9823
# Epoch 129/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0788 - accuracy: 0.9815
# Epoch 130/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0823 - accuracy: 0.9810
# Epoch 131/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0806 - accuracy: 0.9808
# Epoch 132/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0801 - accuracy: 0.9819
# Epoch 133/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0761 - accuracy: 0.9832
# Epoch 134/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0796 - accuracy: 0.9818
# Epoch 135/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0782 - accuracy: 0.9819
# Epoch 136/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0738 - accuracy: 0.9828
# Epoch 137/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0774 - accuracy: 0.9818
# Epoch 138/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0765 - accuracy: 0.9826
# Epoch 139/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0747 - accuracy: 0.9823
# Epoch 140/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0749 - accuracy: 0.9826
# Epoch 141/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0764 - accuracy: 0.9822
# Epoch 142/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0729 - accuracy: 0.9830
# Epoch 143/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0727 - accuracy: 0.9836
# Epoch 144/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0718 - accuracy: 0.9838
# Epoch 145/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0713 - accuracy: 0.9842
# Epoch 146/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0704 - accuracy: 0.9838
# Epoch 147/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0681 - accuracy: 0.9848
# Epoch 148/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0669 - accuracy: 0.9846
# Epoch 149/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0722 - accuracy: 0.9830
# Epoch 150/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0701 - accuracy: 0.9839
# Epoch 151/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0725 - accuracy: 0.9835
# Epoch 152/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0704 - accuracy: 0.9836
# Epoch 153/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0696 - accuracy: 0.9840
# Epoch 154/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0680 - accuracy: 0.9844
# Epoch 155/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0681 - accuracy: 0.9841
# Epoch 156/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0680 - accuracy: 0.9836
# Epoch 157/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0678 - accuracy: 0.9841
# Epoch 158/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0641 - accuracy: 0.9856
# Epoch 159/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0670 - accuracy: 0.9852
# Epoch 160/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0656 - accuracy: 0.9860
# Epoch 161/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0653 - accuracy: 0.9853
# Epoch 162/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0652 - accuracy: 0.9855
# Epoch 163/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0674 - accuracy: 0.9836
# Epoch 164/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0640 - accuracy: 0.9860
# Epoch 165/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0597 - accuracy: 0.9861
# Epoch 166/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0639 - accuracy: 0.9855
# Epoch 167/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0613 - accuracy: 0.9856
# Epoch 168/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0604 - accuracy: 0.9863
# Epoch 169/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0610 - accuracy: 0.9862
# Epoch 170/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0595 - accuracy: 0.9861
# Epoch 171/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0631 - accuracy: 0.9858
# Epoch 172/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0616 - accuracy: 0.9853
# Epoch 173/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0581 - accuracy: 0.9869
# Epoch 174/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0583 - accuracy: 0.9865
# Epoch 175/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0572 - accuracy: 0.9862
# Epoch 176/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0561 - accuracy: 0.9870
# Epoch 177/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0631 - accuracy: 0.9849
# Epoch 178/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0590 - accuracy: 0.9871
# Epoch 179/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0573 - accuracy: 0.9866
# Epoch 180/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0581 - accuracy: 0.9866
# Epoch 181/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0597 - accuracy: 0.9864
# Epoch 182/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0582 - accuracy: 0.9863
# Epoch 183/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0574 - accuracy: 0.9869
# Epoch 184/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0568 - accuracy: 0.9861
# Epoch 185/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0585 - accuracy: 0.9864
# Epoch 186/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0571 - accuracy: 0.9866
# Epoch 187/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0528 - accuracy: 0.9873
# Epoch 188/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0565 - accuracy: 0.9865
# Epoch 189/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0529 - accuracy: 0.9875
# Epoch 190/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0556 - accuracy: 0.9876
# Epoch 191/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0533 - accuracy: 0.9885
# Epoch 192/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0558 - accuracy: 0.9873
# Epoch 193/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0554 - accuracy: 0.9870
# Epoch 194/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0526 - accuracy: 0.9876
# Epoch 195/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0513 - accuracy: 0.9882
# Epoch 196/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0518 - accuracy: 0.9877
# Epoch 197/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0517 - accuracy: 0.9876
# Epoch 198/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0504 - accuracy: 0.9883
# Epoch 199/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0508 - accuracy: 0.9885
# Epoch 200/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0528 - accuracy: 0.9874
# Epoch 201/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0522 - accuracy: 0.9873
# Epoch 202/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0536 - accuracy: 0.9875
# Epoch 203/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0523 - accuracy: 0.9882
# Epoch 204/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0504 - accuracy: 0.9880
# Epoch 205/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0514 - accuracy: 0.9878
# Epoch 206/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0516 - accuracy: 0.9882
# Epoch 207/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0499 - accuracy: 0.9891
# Epoch 208/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0495 - accuracy: 0.9879
# Epoch 209/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0504 - accuracy: 0.9882
# Epoch 210/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0496 - accuracy: 0.9883
# Epoch 211/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0478 - accuracy: 0.9884
# Epoch 212/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0480 - accuracy: 0.9886
# Epoch 213/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0470 - accuracy: 0.9884
# Epoch 214/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0512 - accuracy: 0.9883
# Epoch 215/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0498 - accuracy: 0.9879
# Epoch 216/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0491 - accuracy: 0.9891
# Epoch 217/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0472 - accuracy: 0.9897
# Epoch 218/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0464 - accuracy: 0.9893
# Epoch 219/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0473 - accuracy: 0.9894
# Epoch 220/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0486 - accuracy: 0.9889
# Epoch 221/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0468 - accuracy: 0.9891
# Epoch 222/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0480 - accuracy: 0.9884
# Epoch 223/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0492 - accuracy: 0.9878
# Epoch 224/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0454 - accuracy: 0.9892
# Epoch 225/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0463 - accuracy: 0.9893
# Epoch 226/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0456 - accuracy: 0.9893
# Epoch 227/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0462 - accuracy: 0.9896
# Epoch 228/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0444 - accuracy: 0.9899
# Epoch 229/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0447 - accuracy: 0.9896
# Epoch 230/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0450 - accuracy: 0.9897
# Epoch 231/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0443 - accuracy: 0.9894
# Epoch 232/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0433 - accuracy: 0.9902
# Epoch 233/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0443 - accuracy: 0.9896
# Epoch 234/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0422 - accuracy: 0.9902
# Epoch 235/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0427 - accuracy: 0.9904
# Epoch 236/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0465 - accuracy: 0.9891
# Epoch 237/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0461 - accuracy: 0.9889
# Epoch 238/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0438 - accuracy: 0.9896
# Epoch 239/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0442 - accuracy: 0.9899
# Epoch 240/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0464 - accuracy: 0.9895
# Epoch 241/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0423 - accuracy: 0.9900
# Epoch 242/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0434 - accuracy: 0.9898
# Epoch 243/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0440 - accuracy: 0.9897
# Epoch 244/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0429 - accuracy: 0.9900
# Epoch 245/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0405 - accuracy: 0.9904
# Epoch 246/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0419 - accuracy: 0.9894
# Epoch 247/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0457 - accuracy: 0.9899
# Epoch 248/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0435 - accuracy: 0.9889
# Epoch 249/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0414 - accuracy: 0.9901
# Epoch 250/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0416 - accuracy: 0.9907
# Epoch 251/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0403 - accuracy: 0.9907
# Epoch 252/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0382 - accuracy: 0.9910
# Epoch 253/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0407 - accuracy: 0.9903
# Epoch 254/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0403 - accuracy: 0.9913
# Epoch 255/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0420 - accuracy: 0.9902
# Epoch 256/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0419 - accuracy: 0.9898
# Epoch 257/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0396 - accuracy: 0.9903
# Epoch 258/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0421 - accuracy: 0.9898
# Epoch 259/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0410 - accuracy: 0.9908
# Epoch 260/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0417 - accuracy: 0.9900
# Epoch 261/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0402 - accuracy: 0.9909
# Epoch 262/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0399 - accuracy: 0.9906
# Epoch 263/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0393 - accuracy: 0.9905
# Epoch 264/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0386 - accuracy: 0.9912
# Epoch 265/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0367 - accuracy: 0.9910
# Epoch 266/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0386 - accuracy: 0.9912
# Epoch 267/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0364 - accuracy: 0.9914
# Epoch 268/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0386 - accuracy: 0.9911
# Epoch 269/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0379 - accuracy: 0.9912
# Epoch 270/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0361 - accuracy: 0.9914
# Epoch 271/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0374 - accuracy: 0.9914
# Epoch 272/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0364 - accuracy: 0.9912
# Epoch 273/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0377 - accuracy: 0.9909
# Epoch 274/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0389 - accuracy: 0.9908
# Epoch 275/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0363 - accuracy: 0.9910
# Epoch 276/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0359 - accuracy: 0.9915
# Epoch 277/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0374 - accuracy: 0.9912
# Epoch 278/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0343 - accuracy: 0.9922
# Epoch 279/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0359 - accuracy: 0.9917
# Epoch 280/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0340 - accuracy: 0.9925
# Epoch 281/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0382 - accuracy: 0.9908
# Epoch 282/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0370 - accuracy: 0.9911
# Epoch 283/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0340 - accuracy: 0.9925
# Epoch 284/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0376 - accuracy: 0.9913
# Epoch 285/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0355 - accuracy: 0.9920
# Epoch 286/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0365 - accuracy: 0.9913
# Epoch 287/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0347 - accuracy: 0.9915
# Epoch 288/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0364 - accuracy: 0.9914
# Epoch 289/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0336 - accuracy: 0.9917
# Epoch 290/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0341 - accuracy: 0.9917
# Epoch 291/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0344 - accuracy: 0.9918
# Epoch 292/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0343 - accuracy: 0.9922
# Epoch 293/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0363 - accuracy: 0.9917
# Epoch 294/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0373 - accuracy: 0.9910
# Epoch 295/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0348 - accuracy: 0.9911
# Epoch 296/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0357 - accuracy: 0.9918
# Epoch 297/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0364 - accuracy: 0.9913
# Epoch 298/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0376 - accuracy: 0.9911
# Epoch 299/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0355 - accuracy: 0.9921
# Epoch 300/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0367 - accuracy: 0.9914
# Epoch 301/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0346 - accuracy: 0.9912
# Epoch 302/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0331 - accuracy: 0.9919
# Epoch 303/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0351 - accuracy: 0.9917
# Epoch 304/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0352 - accuracy: 0.9921
# Epoch 305/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0361 - accuracy: 0.9914
# Epoch 306/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0331 - accuracy: 0.9926
# Epoch 307/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0340 - accuracy: 0.9924
# Epoch 308/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0336 - accuracy: 0.9916
# Epoch 309/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0356 - accuracy: 0.9916
# Epoch 310/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0330 - accuracy: 0.9919
# Epoch 311/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0341 - accuracy: 0.9923
# Epoch 312/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0315 - accuracy: 0.9924
# Epoch 313/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0332 - accuracy: 0.9922
# Epoch 314/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0311 - accuracy: 0.9924
# Epoch 315/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0347 - accuracy: 0.9915
# Epoch 316/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0322 - accuracy: 0.9919
# Epoch 317/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0332 - accuracy: 0.9922
# Epoch 318/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0336 - accuracy: 0.9920
# Epoch 319/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0295 - accuracy: 0.9930
# Epoch 320/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0321 - accuracy: 0.9921
# Epoch 321/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0332 - accuracy: 0.9919
# Epoch 322/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0319 - accuracy: 0.9923
# Epoch 323/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0329 - accuracy: 0.9919
# Epoch 324/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0342 - accuracy: 0.9915
# Epoch 325/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0310 - accuracy: 0.9926
# Epoch 326/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0300 - accuracy: 0.9923
# Epoch 327/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0322 - accuracy: 0.9926
# Epoch 328/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0327 - accuracy: 0.9919
# Epoch 329/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0292 - accuracy: 0.9931
# Epoch 330/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0312 - accuracy: 0.9927
# Epoch 331/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0282 - accuracy: 0.9932
# Epoch 332/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0292 - accuracy: 0.9931
# Epoch 333/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0311 - accuracy: 0.9923
# Epoch 334/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0329 - accuracy: 0.9921
# Epoch 335/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0327 - accuracy: 0.9927
# Epoch 336/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0294 - accuracy: 0.9928
# Epoch 337/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0313 - accuracy: 0.9925
# Epoch 338/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0306 - accuracy: 0.9932
# Epoch 339/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0307 - accuracy: 0.9929
# Epoch 340/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0309 - accuracy: 0.9924
# Epoch 341/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0318 - accuracy: 0.9924
# Epoch 342/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0308 - accuracy: 0.9927
# Epoch 343/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0311 - accuracy: 0.9929
# Epoch 344/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0291 - accuracy: 0.9931
# Epoch 345/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0293 - accuracy: 0.9929
# Epoch 346/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0287 - accuracy: 0.9930
# Epoch 347/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0291 - accuracy: 0.9929
# Epoch 348/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0308 - accuracy: 0.9925
# Epoch 349/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0266 - accuracy: 0.9940
# Epoch 350/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0292 - accuracy: 0.9927
# Epoch 351/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0289 - accuracy: 0.9928
# Epoch 352/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0311 - accuracy: 0.9919
# Epoch 353/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0293 - accuracy: 0.9927
# Epoch 354/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0289 - accuracy: 0.9933
# Epoch 355/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0282 - accuracy: 0.9934
# Epoch 356/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0292 - accuracy: 0.9931
# Epoch 357/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0302 - accuracy: 0.9931
# Epoch 358/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0265 - accuracy: 0.9938
# Epoch 359/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0255 - accuracy: 0.9944
# Epoch 360/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0276 - accuracy: 0.9938
# Epoch 361/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0272 - accuracy: 0.9933
# Epoch 362/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0289 - accuracy: 0.9923
# Epoch 363/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0272 - accuracy: 0.9939
# Epoch 364/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0280 - accuracy: 0.9934
# Epoch 365/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0266 - accuracy: 0.9935
# Epoch 366/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0301 - accuracy: 0.9929
# Epoch 367/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0278 - accuracy: 0.9932
# Epoch 368/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0288 - accuracy: 0.9927
# Epoch 369/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0276 - accuracy: 0.9937
# Epoch 370/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0281 - accuracy: 0.9933
# Epoch 371/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0254 - accuracy: 0.9938
# Epoch 372/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0285 - accuracy: 0.9929
# Epoch 373/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0263 - accuracy: 0.9935
# Epoch 374/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0263 - accuracy: 0.9939
# Epoch 375/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0263 - accuracy: 0.9937
# Epoch 376/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0276 - accuracy: 0.9934
# Epoch 377/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0265 - accuracy: 0.9934
# Epoch 378/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0257 - accuracy: 0.9942
# Epoch 379/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0257 - accuracy: 0.9938
# Epoch 380/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0249 - accuracy: 0.9942
# Epoch 381/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0258 - accuracy: 0.9936
# Epoch 382/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0261 - accuracy: 0.9939
# Epoch 383/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0251 - accuracy: 0.9942
# Epoch 384/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0276 - accuracy: 0.9936
# Epoch 385/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0263 - accuracy: 0.9936
# Epoch 386/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0258 - accuracy: 0.9936
# Epoch 387/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0267 - accuracy: 0.9936
# Epoch 388/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0260 - accuracy: 0.9940
# Epoch 389/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0247 - accuracy: 0.9946
# Epoch 390/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0254 - accuracy: 0.9941
# Epoch 391/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0259 - accuracy: 0.9943
# Epoch 392/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0248 - accuracy: 0.9940
# Epoch 393/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0250 - accuracy: 0.9939
# Epoch 394/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0268 - accuracy: 0.9936
# Epoch 395/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0260 - accuracy: 0.9936
# Epoch 396/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0288 - accuracy: 0.9932
# Epoch 397/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0261 - accuracy: 0.9938
# Epoch 398/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0263 - accuracy: 0.9933
# Epoch 399/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0279 - accuracy: 0.9930
# Epoch 400/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0269 - accuracy: 0.9936
# Epoch 401/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0261 - accuracy: 0.9941
# Epoch 402/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0246 - accuracy: 0.9935
# Epoch 403/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0255 - accuracy: 0.9943
# Epoch 404/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0261 - accuracy: 0.9934
# Epoch 405/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0267 - accuracy: 0.9936
# Epoch 406/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0239 - accuracy: 0.9945
# Epoch 407/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0262 - accuracy: 0.9939
# Epoch 408/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0244 - accuracy: 0.9943
# Epoch 409/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0262 - accuracy: 0.9935
# Epoch 410/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0245 - accuracy: 0.9942
# Epoch 411/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0263 - accuracy: 0.9939
# Epoch 412/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0260 - accuracy: 0.9933
# Epoch 413/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0229 - accuracy: 0.9945
# Epoch 414/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0248 - accuracy: 0.9945
# Epoch 415/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0245 - accuracy: 0.9945
# Epoch 416/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0246 - accuracy: 0.9941
# Epoch 417/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0247 - accuracy: 0.9940
# Epoch 418/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0244 - accuracy: 0.9940
# Epoch 419/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0239 - accuracy: 0.9942
# Epoch 420/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0230 - accuracy: 0.9946
# Epoch 421/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0246 - accuracy: 0.9943
# Epoch 422/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0228 - accuracy: 0.9946
# Epoch 423/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0234 - accuracy: 0.9941
# Epoch 424/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0224 - accuracy: 0.9943
# Epoch 425/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0232 - accuracy: 0.9948
# Epoch 426/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0247 - accuracy: 0.9940
# Epoch 427/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0250 - accuracy: 0.9937
# Epoch 428/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0240 - accuracy: 0.9939
# Epoch 429/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0243 - accuracy: 0.9939
# Epoch 430/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0222 - accuracy: 0.9947
# Epoch 431/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0243 - accuracy: 0.9944
# Epoch 432/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0242 - accuracy: 0.9943
# Epoch 433/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0217 - accuracy: 0.9946
# Epoch 434/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0222 - accuracy: 0.9947
# Epoch 435/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0231 - accuracy: 0.9944
# Epoch 436/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0237 - accuracy: 0.9936
# Epoch 437/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0221 - accuracy: 0.9942
# Epoch 438/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0217 - accuracy: 0.9951
# Epoch 439/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0253 - accuracy: 0.9939
# Epoch 440/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0240 - accuracy: 0.9942
# Epoch 441/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0228 - accuracy: 0.9944
# Epoch 442/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0226 - accuracy: 0.9943
# Epoch 443/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0227 - accuracy: 0.9949
# Epoch 444/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0237 - accuracy: 0.9941
# Epoch 445/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0236 - accuracy: 0.9943
# Epoch 446/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0238 - accuracy: 0.9945
# Epoch 447/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0218 - accuracy: 0.9943
# Epoch 448/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0234 - accuracy: 0.9943
# Epoch 449/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0230 - accuracy: 0.9945
# Epoch 450/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0233 - accuracy: 0.9940
# Epoch 451/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0226 - accuracy: 0.9948
# Epoch 452/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0234 - accuracy: 0.9941
# Epoch 453/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0228 - accuracy: 0.9938
# Epoch 454/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0212 - accuracy: 0.9949
# Epoch 455/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0207 - accuracy: 0.9949
# Epoch 456/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0233 - accuracy: 0.9943
# Epoch 457/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0232 - accuracy: 0.9939
# Epoch 458/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0230 - accuracy: 0.9945
# Epoch 459/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0212 - accuracy: 0.9944
# Epoch 460/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0234 - accuracy: 0.9944
# Epoch 461/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0214 - accuracy: 0.9949
# Epoch 462/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0219 - accuracy: 0.9948
# Epoch 463/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0225 - accuracy: 0.9946
# Epoch 464/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0214 - accuracy: 0.9949
# Epoch 465/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0210 - accuracy: 0.9946
# Epoch 466/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0223 - accuracy: 0.9945
# Epoch 467/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0221 - accuracy: 0.9947
# Epoch 468/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0208 - accuracy: 0.9950
# Epoch 469/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0194 - accuracy: 0.9956
# Epoch 470/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0225 - accuracy: 0.9949
# Epoch 471/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0212 - accuracy: 0.9950
# Epoch 472/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0221 - accuracy: 0.9947
# Epoch 473/500
# 306/306 [==============================] - 6s 18ms/step - loss: 0.0214 - accuracy: 0.9950
# Epoch 474/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0226 - accuracy: 0.9947
# Epoch 475/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0221 - accuracy: 0.9949
# Epoch 476/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0207 - accuracy: 0.9948
# Epoch 477/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0212 - accuracy: 0.9946
# Epoch 478/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0196 - accuracy: 0.9955
# Epoch 479/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0226 - accuracy: 0.9943
# Epoch 480/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0208 - accuracy: 0.9948
# Epoch 481/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0207 - accuracy: 0.9950
# Epoch 482/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0215 - accuracy: 0.9945
# Epoch 483/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0215 - accuracy: 0.9946
# Epoch 484/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0200 - accuracy: 0.9954
# Epoch 485/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0190 - accuracy: 0.9953
# Epoch 486/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0211 - accuracy: 0.9950
# Epoch 487/500
# 306/306 [==============================] - 6s 19ms/step - loss: 0.0213 - accuracy: 0.9947
# Epoch 488/500
# 306/306 [==============================] - 6s 20ms/step - loss: 0.0205 - accuracy: 0.9948
# Epoch 489/500
# 306/306 [==============================] - 5s 17ms/step - loss: 0.0200 - accuracy: 0.9951
# Epoch 490/500
# 306/306 [==============================] - 5s 18ms/step - loss: 0.0199 - accuracy: 0.9953
# Epoch 491/500
# 157/306 [==============>...............] - ETA: 2s - loss: 0.0226 - accuracy: 0.9944

# %% [markdown]
# Let's evaluate the model:

# %%
eval_train_ds = prepare_for_evaluation(labeled_ds_train)
eval_test_ds = prepare_for_evaluation(labeled_ds_test)
train_results = model.evaluate(eval_train_ds)
print('Train loss, train acc:', results)
test_results = model.evaluate(eval_test_ds)
print('Test loss, test acc:', results)

# %% [markdown]
# There are lot of ways to improve the model above. According to Stallkamp et al. (2012), an ensemble of CNNs can reach 99.46%. Good human performance is
# 99.22%.

# %%
Experiment.end(self)

# %%
# Original
