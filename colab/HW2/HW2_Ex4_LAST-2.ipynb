# %% [markdown]
# # Small CNN for traffic sign recognition as template for  assignment
# ## Christian Igel, 2020
#
# This notebook provides a template for a small CNN for the German Traffic Sign Recognition Benchmark. The data is described in:
#
# Johannes Stallkamp, Marc Schlipsing, Jan Salmen, and Christian Igel. Man vs. Computer: Benchmarking Machine Learning Algorithms for Traffic Sign Recognition. *Neural Networks* **32**, pp. 323-332, 2012
#
# This notebook is a template, without modification the model does not even come close to the state-of-the-art.

# %%
# Install, restart runtime, run all
# !pip install comet_ml
# Out:
# Requirement already satisfied: comet_ml in /usr/local/lib/python3.6/dist-packages (3.1.6)
# Requirement already satisfied: comet-git-pure>=0.19.11 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (0.19.16)
# Requirement already satisfied: jsonschema<3.1.0,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (2.6.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (2.23.0)
# Requirement already satisfied: websocket-client>=0.55.0 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (0.57.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (2.0.0)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (7.352.0)
# Requirement already satisfied: netifaces>=0.10.7 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (0.10.9)
# Requirement already satisfied: everett[ini]>=1.0.1; python_version >= "3.0" in /usr/local/lib/python3.6/dist-packages (from comet_ml) (1.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from comet_ml) (3.7.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from comet_ml) (1.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from comet-git-pure>=0.19.11->comet_ml) (2020.4.5.1)
# Requirement already satisfied: urllib3>=1.24.1 in /usr/local/lib/python3.6/dist-packages (from comet-git-pure>=0.19.11->comet_ml) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->comet_ml) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->comet_ml) (2.9)
# Requirement already satisfied: configobj; extra == "ini" in /usr/local/lib/python3.6/dist-packages (from everett[ini]>=1.0.1; python_version >= "3.0"->comet_ml) (5.0.6)

# %%
## For reproducibility
from comet_ml import Experiment

seed_value = 420420
experiment = Experiment(api_key="zmx2tdNM2D3GnUg4jtTLpQ2Vy",
                        project_name="HW2_Version0", workspace="lallakala")
tags = "Conv(32,64,128)(5,5,3)", "Batchnorm < Conv2D"             #  0.05 learning rate
Experiment.add_tags(experiment, tags)
Experiment.set_filename(experiment, "Notebook6")
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/lallakala/hw2-version0/0f4cfb7b424144e9a5e99aa250717745

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt 
import numpy as np
import pathlib
import os

print("TensorFlow version:", tf.__version__)

AUTOTUNE = tf.data.experimental.AUTOTUNE
# Out:
# TensorFlow version: 2.2.0-rc4

# %% [markdown]
# # FILE REPRODUCIBILITY

# %%
experiment.log_other("random seed", seed_value)

# Set the seed value for all the frameworks
os.environ['PYTHONHASHSEED']=str(seed_value)

import random
random.seed(seed_value)

np.random.seed(seed_value)

tf.random.set_seed(seed_value)

# set seed values                                   # add that if use dropout
# model.add(Dropout(0.25, seed=seed_value))

# Configure a new global `tensorflow` session
#from keras import backend as K
#session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
#sess = tf.compat.v1.Session()(graph=tf.compat.v1.get_default_graph(), config=session_conf)
#K.set_session(sess)

# %% [markdown]
# Download the data:

# %%
data_root="."
tf.keras.utils.get_file("GTSRB.zip",
                        "https://sid.erda.dk/share_redirect/EB0rrpZwuI",
                        cache_dir=data_root,
                        extract=True)
# Out:
# './datasets/GTSRB.zip'

# %% [markdown]
# The images are stored in subdirectories. The names of the subdirectories encode the class labels.

# %%
# Determine the number of training and test images
n_train = len(list(pathlib.Path(data_root).glob("datasets/GTSRB/train/*/*")))
n_test = len(list(pathlib.Path(data_root).glob("datasets/GTSRB/test/*/*")))

print("Number of training images:", n_train)
print("Number of test images:" ,n_test)
# Out:
# Number of training images: 39209
# Number of test images: 12630

# %% [markdown]
# Some basic constants:

# %%
no_classes = 43  # There are 43 different signs
no_channels = 3  # We are dealing with color images

# All images are initially resized to img_height x img_width
img_height  = 32  
img_width   = 32
# During training and testing the  images are cropped to img_height_crop x img_width_crop
img_height_crop = 28  
img_width_crop  = 28

batch_size = 128
steps_per_epoch = n_train // batch_size  # How many batches are there in each epoch?

# %% [markdown]
# Helper function for extracting the label information from the paths to the images and loading and preprocessing the images:

# %%
# Extract the label from the file path
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return tf.strings.to_number(parts[-2], tf.int32)

# Load image, convert it to floats, and resize it
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=no_channels)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # Resize the image to the desired size.
  return tf.image.resize(img, [img_width, img_height])

# Given the path and filename of an image, create the label and the input image
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# Create data sets based on the files:

# %%
# Tell dataset the lists of files containing the trainig and test images, respectively
list_ds_train = tf.data.Dataset.list_files(data_root + "/datasets/GTSRB/train/*/*")
list_ds_test  = tf.data.Dataset.list_files(data_root + "/datasets/GTSRB/test/*/*", shuffle=False)  # Fixed order for test time augemantation 

# Tell dataset how to extract images and labels
labeled_ds_train = list_ds_train.map(process_path, num_parallel_calls=AUTOTUNE)
labeled_ds_test = list_ds_test.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Functions for data preprocessing/augmentation:

# %%
# Used for training data augmentation
def augment(image, label):
    image = tf.image.random_crop(image, [img_height_crop, img_width_crop, no_channels])
    image = tf.case([(tf.equal(label, 11), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 12), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 13), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 17), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 18), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 26), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 30), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 35), lambda: tf.image.random_flip_left_right(image))], default = lambda: image)
    image = tf.image.random_brightness(image, max_delta=0.1) # Random brightness
    image = tf.clip_by_value(image, 0., 1.)
    return image, label

# Used for testing/evaluation
def crop_center(image, label):
  image = tf.image.resize_with_crop_or_pad(image, img_height_crop, img_width_crop)
  return image, label

# Could be used for test time augementation
def crop_random(image, label):
  image = tf.image.random_crop(image, [img_height_crop, img_width_crop, no_channels])
  return image, label

# %% [markdown]
# We prepare the data for training and testing differently. For example, for training we use data augmentation.

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  # `.cache(filename)` is used to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):  # Is the chache argument a string?
      ds = ds.cache(cache)  # If yes, we cache to a file
    else:
      ds = ds.cache()  
  # We shuffle the data after the caching
  ds = ds.shuffle(buffer_size=shuffle_buffer_size, reshuffle_each_iteration=True)
  # Repeat forever
  ds = ds.repeat()
  # Do data augmentation
  ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
  # Partition in batches
  ds = ds.batch(batch_size)
  # Fetch batches in the background while the model training
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

def prepare_for_evaluation(ds, shuffle_buffer_size=1000):
  # For normal evaluation, we look at the center of the image
  ds = ds.map(crop_center, num_parallel_calls=AUTOTUNE)
  # Partition in batches
  ds = ds.batch(batch_size)
  # Fetch batches in the background while the model training
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

def prepare_for_augmented_evaluation(ds):
  ds = ds.map(crop_random, num_parallel_calls=AUTOTUNE)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# Make training dataset 
train_ds = prepare_for_training(labeled_ds_train)

# Make test dataset 
test_ds = prepare_for_evaluation(labeled_ds_train)

# %% [markdown]
# Let's have a look at a random batch of images:

# %%
# Helper function for displaying images
def show_batch(image_batch, label_batch, nrows=6, ncols=6):
  plt.figure(figsize=(10,10))
  for n in range(nrows*ncols):
      ax = plt.subplot(nrows, ncols, n+1)
      if no_channels == 3:
        plt.imshow(image_batch[n])
      else:
        plt.imshow(image_batch[n].reshape([img_height_crop, img_width_crop]))
      plt.title('class:' + str(label_batch[n]))
      plt.axis('off')

# Get a batch of images and labels
image_batch, label_batch = next(iter(train_ds))

# Visualize images and labels
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# Define a neural network model:

# %%
sd_init = 0.01  # Standard deviation and offset for initializing bias parameters in hidden layers
sd_mean = 0.05

# set seed values 
# model.add(Dropout(0.25, seed=seed_value))

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), activation=None,  
                           input_shape=(img_width_crop, img_height_crop, no_channels),
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_mean, stddev=sd_init)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.25, seed=seed_value),
    tf.keras.layers.Conv2D(64, (5, 5), activation=None, 
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_mean, stddev=sd_init)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.5, seed=seed_value),
    tf.keras.layers.Conv2D(128, (3, 3), activation=None, 
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_mean, stddev=sd_init)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.5, seed=seed_value),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(no_classes, activation='softmax')])
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 24, 24, 32)        128
# _________________________________________________________________
# elu (ELU)                    (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# elu_1 (ELU)                  (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# elu_2 (ELU)                  (None, 2, 2, 128)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 43)                5547
# =================================================================
# Total params: 133,995
# Trainable params: 133,547
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# Define optimizer and compile the model:

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.05, epsilon=0.1)
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])  # sparse categorical crossentropy does the one hot encoding for us under the hood

# %% [markdown]
# Do the learning:

# %%
# Train the model
import time
start = time.time()

history = model.fit(train_ds, epochs=800, steps_per_epoch=steps_per_epoch)

print("Training took", (time.time() - start)/60, "minutes.")
# Out:
# COMET INFO: Ignoring automatic log_parameter('verbose') because 'keras:verbose' is in COMET_LOGGING_PARAMETERS_IGNORE
# Epoch 1/800
# 306/306 [==============================] - 25s 82ms/step - loss: 2.2900 - accuracy: 0.3741
# Epoch 2/800
# 306/306 [==============================] - 9s 29ms/step - loss: 0.9605 - accuracy: 0.7076
# Epoch 3/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.5779 - accuracy: 0.8316
# Epoch 4/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.4317 - accuracy: 0.8758
# Epoch 5/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.3498 - accuracy: 0.9016
# Epoch 6/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.3093 - accuracy: 0.9116
# Epoch 7/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.2652 - accuracy: 0.9247
# Epoch 8/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.2469 - accuracy: 0.9300
# Epoch 9/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.2254 - accuracy: 0.9347
# Epoch 10/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.2143 - accuracy: 0.9397
# Epoch 11/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.1975 - accuracy: 0.9430
# Epoch 12/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1986 - accuracy: 0.9430
# Epoch 13/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1789 - accuracy: 0.9490
# Epoch 14/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1697 - accuracy: 0.9508
# Epoch 15/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.1690 - accuracy: 0.9528
# Epoch 16/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1584 - accuracy: 0.9531
# Epoch 17/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1497 - accuracy: 0.9570
# Epoch 18/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.1581 - accuracy: 0.9547
# Epoch 19/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1440 - accuracy: 0.9578
# Epoch 20/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1392 - accuracy: 0.9614
# Epoch 21/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.1374 - accuracy: 0.9615
# Epoch 22/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.1324 - accuracy: 0.9618
# Epoch 23/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.1297 - accuracy: 0.9629
# Epoch 24/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1286 - accuracy: 0.9634
# Epoch 25/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1299 - accuracy: 0.9634
# Epoch 26/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1224 - accuracy: 0.9656
# Epoch 27/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1205 - accuracy: 0.9657
# Epoch 28/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.1156 - accuracy: 0.9671
# Epoch 29/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1194 - accuracy: 0.9644
# Epoch 30/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1116 - accuracy: 0.9674
# Epoch 31/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.1100 - accuracy: 0.9689
# Epoch 32/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.1195 - accuracy: 0.9665
# Epoch 33/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1083 - accuracy: 0.9697
# Epoch 34/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1061 - accuracy: 0.9699
# Epoch 35/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1099 - accuracy: 0.9687
# Epoch 36/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.1099 - accuracy: 0.9682
# Epoch 37/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1114 - accuracy: 0.9683
# Epoch 38/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1029 - accuracy: 0.9708
# Epoch 39/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1068 - accuracy: 0.9698
# Epoch 40/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.1052 - accuracy: 0.9706
# Epoch 41/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0968 - accuracy: 0.9726
# Epoch 42/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.1036 - accuracy: 0.9707
# Epoch 43/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0956 - accuracy: 0.9732
# Epoch 44/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.1046 - accuracy: 0.9703
# Epoch 45/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0965 - accuracy: 0.9728
# Epoch 46/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0971 - accuracy: 0.9725
# Epoch 47/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0969 - accuracy: 0.9722
# Epoch 48/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0957 - accuracy: 0.9727
# Epoch 49/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0945 - accuracy: 0.9726
# Epoch 50/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0972 - accuracy: 0.9725
# Epoch 51/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0911 - accuracy: 0.9741
# Epoch 52/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0948 - accuracy: 0.9727
# Epoch 53/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0906 - accuracy: 0.9743
# Epoch 54/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0869 - accuracy: 0.9745
# Epoch 55/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0860 - accuracy: 0.9747
# Epoch 56/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0891 - accuracy: 0.9742
# Epoch 57/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0881 - accuracy: 0.9742
# Epoch 58/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0913 - accuracy: 0.9735
# Epoch 59/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0821 - accuracy: 0.9759
# Epoch 60/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0874 - accuracy: 0.9748
# Epoch 61/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0811 - accuracy: 0.9767
# Epoch 62/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0861 - accuracy: 0.9751
# Epoch 63/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0834 - accuracy: 0.9756
# Epoch 64/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0874 - accuracy: 0.9755
# Epoch 65/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0825 - accuracy: 0.9763
# Epoch 66/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0827 - accuracy: 0.9764
# Epoch 67/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0839 - accuracy: 0.9764
# Epoch 68/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0822 - accuracy: 0.9767
# Epoch 69/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0873 - accuracy: 0.9753
# Epoch 70/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0790 - accuracy: 0.9775
# Epoch 71/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0834 - accuracy: 0.9757
# Epoch 72/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0774 - accuracy: 0.9775
# Epoch 73/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0791 - accuracy: 0.9769
# Epoch 74/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0760 - accuracy: 0.9781
# Epoch 75/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0767 - accuracy: 0.9779
# Epoch 76/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0768 - accuracy: 0.9769
# Epoch 77/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0793 - accuracy: 0.9776
# Epoch 78/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0778 - accuracy: 0.9775
# Epoch 79/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0778 - accuracy: 0.9777
# Epoch 80/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0770 - accuracy: 0.9786
# Epoch 81/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0811 - accuracy: 0.9773
# Epoch 82/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0738 - accuracy: 0.9785
# Epoch 83/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0751 - accuracy: 0.9781
# Epoch 84/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0784 - accuracy: 0.9770
# Epoch 85/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0754 - accuracy: 0.9779
# Epoch 86/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0745 - accuracy: 0.9782
# Epoch 87/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0742 - accuracy: 0.9788
# Epoch 88/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0746 - accuracy: 0.9783
# Epoch 89/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0735 - accuracy: 0.9787
# Epoch 90/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0745 - accuracy: 0.9782
# Epoch 91/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0741 - accuracy: 0.9796
# Epoch 92/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0721 - accuracy: 0.9788
# Epoch 93/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0704 - accuracy: 0.9797
# Epoch 94/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0754 - accuracy: 0.9783
# Epoch 95/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0703 - accuracy: 0.9798
# Epoch 96/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0738 - accuracy: 0.9790
# Epoch 97/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0711 - accuracy: 0.9795
# Epoch 98/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0678 - accuracy: 0.9805
# Epoch 99/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0723 - accuracy: 0.9793
# Epoch 100/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0689 - accuracy: 0.9803
# Epoch 101/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0711 - accuracy: 0.9791
# Epoch 102/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0759 - accuracy: 0.9784
# Epoch 103/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0701 - accuracy: 0.9792
# Epoch 104/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0693 - accuracy: 0.9804
# Epoch 105/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0667 - accuracy: 0.9808
# Epoch 106/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0712 - accuracy: 0.9793
# Epoch 107/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0683 - accuracy: 0.9798
# Epoch 108/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0702 - accuracy: 0.9800
# Epoch 109/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0676 - accuracy: 0.9806
# Epoch 110/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0702 - accuracy: 0.9794
# Epoch 111/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0659 - accuracy: 0.9811
# Epoch 112/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0695 - accuracy: 0.9801
# Epoch 113/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0654 - accuracy: 0.9812
# Epoch 114/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0653 - accuracy: 0.9808
# Epoch 115/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0683 - accuracy: 0.9809
# Epoch 116/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0669 - accuracy: 0.9806
# Epoch 117/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0641 - accuracy: 0.9813
# Epoch 118/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0686 - accuracy: 0.9808
# Epoch 119/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0692 - accuracy: 0.9803
# Epoch 120/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0684 - accuracy: 0.9806
# Epoch 121/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0659 - accuracy: 0.9811
# Epoch 122/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0686 - accuracy: 0.9801
# Epoch 123/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0636 - accuracy: 0.9813
# Epoch 124/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0649 - accuracy: 0.9816
# Epoch 125/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0655 - accuracy: 0.9812
# Epoch 126/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0669 - accuracy: 0.9805
# Epoch 127/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0631 - accuracy: 0.9820
# Epoch 128/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0603 - accuracy: 0.9821
# Epoch 129/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0629 - accuracy: 0.9812
# Epoch 130/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0637 - accuracy: 0.9811
# Epoch 131/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0629 - accuracy: 0.9818
# Epoch 132/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0628 - accuracy: 0.9817
# Epoch 133/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0644 - accuracy: 0.9810
# Epoch 134/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0663 - accuracy: 0.9804
# Epoch 135/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0651 - accuracy: 0.9816
# Epoch 136/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0610 - accuracy: 0.9817
# Epoch 137/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0646 - accuracy: 0.9810
# Epoch 138/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0616 - accuracy: 0.9820
# Epoch 139/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0636 - accuracy: 0.9818
# Epoch 140/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0639 - accuracy: 0.9814
# Epoch 141/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0646 - accuracy: 0.9817
# Epoch 142/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0580 - accuracy: 0.9827
# Epoch 143/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0629 - accuracy: 0.9821
# Epoch 144/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0623 - accuracy: 0.9828
# Epoch 145/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0632 - accuracy: 0.9821
# Epoch 146/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0555 - accuracy: 0.9834
# Epoch 147/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0584 - accuracy: 0.9830
# Epoch 148/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0596 - accuracy: 0.9830
# Epoch 149/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0624 - accuracy: 0.9820
# Epoch 150/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0615 - accuracy: 0.9825
# Epoch 151/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0622 - accuracy: 0.9827
# Epoch 152/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0607 - accuracy: 0.9827
# Epoch 153/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0603 - accuracy: 0.9827
# Epoch 154/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0597 - accuracy: 0.9829
# Epoch 155/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0613 - accuracy: 0.9826
# Epoch 156/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0597 - accuracy: 0.9822
# Epoch 157/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0590 - accuracy: 0.9830
# Epoch 158/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0599 - accuracy: 0.9824
# Epoch 159/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0594 - accuracy: 0.9824
# Epoch 160/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0586 - accuracy: 0.9828
# Epoch 161/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0615 - accuracy: 0.9825
# Epoch 162/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0623 - accuracy: 0.9827
# Epoch 163/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0644 - accuracy: 0.9812
# Epoch 164/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0569 - accuracy: 0.9839
# Epoch 165/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0605 - accuracy: 0.9828
# Epoch 166/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0571 - accuracy: 0.9835
# Epoch 167/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0617 - accuracy: 0.9822
# Epoch 168/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0619 - accuracy: 0.9824
# Epoch 169/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0576 - accuracy: 0.9826
# Epoch 170/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0591 - accuracy: 0.9833
# Epoch 171/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0604 - accuracy: 0.9828
# Epoch 172/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0553 - accuracy: 0.9836
# Epoch 173/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0564 - accuracy: 0.9830
# Epoch 174/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0613 - accuracy: 0.9823
# Epoch 175/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0598 - accuracy: 0.9824
# Epoch 176/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0576 - accuracy: 0.9824
# Epoch 177/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0607 - accuracy: 0.9819
# Epoch 178/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0552 - accuracy: 0.9838
# Epoch 179/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0622 - accuracy: 0.9820
# Epoch 180/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0611 - accuracy: 0.9827
# Epoch 181/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0598 - accuracy: 0.9828
# Epoch 182/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0602 - accuracy: 0.9833
# Epoch 183/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0536 - accuracy: 0.9847
# Epoch 184/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0554 - accuracy: 0.9836
# Epoch 185/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0568 - accuracy: 0.9840
# Epoch 186/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0552 - accuracy: 0.9841
# Epoch 187/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0550 - accuracy: 0.9839
# Epoch 188/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0575 - accuracy: 0.9841
# Epoch 189/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0563 - accuracy: 0.9834
# Epoch 190/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0569 - accuracy: 0.9835
# Epoch 191/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0566 - accuracy: 0.9834
# Epoch 192/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0565 - accuracy: 0.9834
# Epoch 193/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0560 - accuracy: 0.9838
# Epoch 194/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0565 - accuracy: 0.9840
# Epoch 195/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0559 - accuracy: 0.9842
# Epoch 196/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0562 - accuracy: 0.9833
# Epoch 197/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0564 - accuracy: 0.9841
# Epoch 198/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0537 - accuracy: 0.9849
# Epoch 199/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0526 - accuracy: 0.9840
# Epoch 200/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0562 - accuracy: 0.9837
# Epoch 201/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0544 - accuracy: 0.9838
# Epoch 202/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0528 - accuracy: 0.9844
# Epoch 203/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0543 - accuracy: 0.9840
# Epoch 204/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0552 - accuracy: 0.9846
# Epoch 205/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0522 - accuracy: 0.9847
# Epoch 206/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0553 - accuracy: 0.9840
# Epoch 207/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0555 - accuracy: 0.9831
# Epoch 208/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0584 - accuracy: 0.9828
# Epoch 209/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0547 - accuracy: 0.9847
# Epoch 210/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0551 - accuracy: 0.9838
# Epoch 211/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0563 - accuracy: 0.9833
# Epoch 212/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0526 - accuracy: 0.9856
# Epoch 213/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0508 - accuracy: 0.9855
# Epoch 214/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0515 - accuracy: 0.9853
# Epoch 215/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0553 - accuracy: 0.9838
# Epoch 216/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0508 - accuracy: 0.9857
# Epoch 217/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0508 - accuracy: 0.9855
# Epoch 218/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0513 - accuracy: 0.9850
# Epoch 219/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0522 - accuracy: 0.9850
# Epoch 220/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0521 - accuracy: 0.9850
# Epoch 221/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0523 - accuracy: 0.9845
# Epoch 222/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0500 - accuracy: 0.9851
# Epoch 223/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0579 - accuracy: 0.9836
# Epoch 224/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0539 - accuracy: 0.9839
# Epoch 225/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0532 - accuracy: 0.9843
# Epoch 226/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0531 - accuracy: 0.9847
# Epoch 227/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0544 - accuracy: 0.9851
# Epoch 228/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0532 - accuracy: 0.9840
# Epoch 229/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0538 - accuracy: 0.9837
# Epoch 230/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0506 - accuracy: 0.9851
# Epoch 231/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0518 - accuracy: 0.9854
# Epoch 232/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0531 - accuracy: 0.9849
# Epoch 233/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0555 - accuracy: 0.9840
# Epoch 234/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0527 - accuracy: 0.9847
# Epoch 235/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0540 - accuracy: 0.9848
# Epoch 236/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0555 - accuracy: 0.9842
# Epoch 237/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0556 - accuracy: 0.9843
# Epoch 238/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0533 - accuracy: 0.9842
# Epoch 239/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0489 - accuracy: 0.9861
# Epoch 240/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0550 - accuracy: 0.9840
# Epoch 241/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0516 - accuracy: 0.9851
# Epoch 242/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0506 - accuracy: 0.9862
# Epoch 243/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0517 - accuracy: 0.9849
# Epoch 244/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0508 - accuracy: 0.9858
# Epoch 245/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0507 - accuracy: 0.9852
# Epoch 246/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0496 - accuracy: 0.9861
# Epoch 247/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0551 - accuracy: 0.9846
# Epoch 248/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0498 - accuracy: 0.9860
# Epoch 249/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0523 - accuracy: 0.9845
# Epoch 250/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0514 - accuracy: 0.9849
# Epoch 251/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0495 - accuracy: 0.9858
# Epoch 252/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0486 - accuracy: 0.9859
# Epoch 253/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0485 - accuracy: 0.9859
# Epoch 254/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0516 - accuracy: 0.9854
# Epoch 255/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0489 - accuracy: 0.9856
# Epoch 256/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0533 - accuracy: 0.9848
# Epoch 257/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0491 - accuracy: 0.9858
# Epoch 258/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0537 - accuracy: 0.9840
# Epoch 259/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0481 - accuracy: 0.9858
# Epoch 260/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0547 - accuracy: 0.9846
# Epoch 261/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0505 - accuracy: 0.9854
# Epoch 262/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0528 - accuracy: 0.9846
# Epoch 263/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0503 - accuracy: 0.9858
# Epoch 264/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0521 - accuracy: 0.9852
# Epoch 265/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0486 - accuracy: 0.9858
# Epoch 266/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0484 - accuracy: 0.9856
# Epoch 267/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0494 - accuracy: 0.9854
# Epoch 268/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0466 - accuracy: 0.9861
# Epoch 269/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0497 - accuracy: 0.9853
# Epoch 270/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0480 - accuracy: 0.9859
# Epoch 271/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0473 - accuracy: 0.9866
# Epoch 272/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0490 - accuracy: 0.9861
# Epoch 273/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0485 - accuracy: 0.9862
# Epoch 274/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0497 - accuracy: 0.9860
# Epoch 275/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0483 - accuracy: 0.9862
# Epoch 276/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0514 - accuracy: 0.9853
# Epoch 277/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0486 - accuracy: 0.9861
# Epoch 278/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0462 - accuracy: 0.9867
# Epoch 279/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0495 - accuracy: 0.9858
# Epoch 280/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0459 - accuracy: 0.9870
# Epoch 281/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0506 - accuracy: 0.9864
# Epoch 282/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0461 - accuracy: 0.9864
# Epoch 283/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0472 - accuracy: 0.9863
# Epoch 284/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0478 - accuracy: 0.9865
# Epoch 285/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0495 - accuracy: 0.9858
# Epoch 286/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0549 - accuracy: 0.9841
# Epoch 287/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0486 - accuracy: 0.9854
# Epoch 288/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0483 - accuracy: 0.9855
# Epoch 289/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0498 - accuracy: 0.9856
# Epoch 290/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0465 - accuracy: 0.9862
# Epoch 291/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0473 - accuracy: 0.9861
# Epoch 292/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0481 - accuracy: 0.9855
# Epoch 293/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0456 - accuracy: 0.9866
# Epoch 294/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0455 - accuracy: 0.9866
# Epoch 295/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0496 - accuracy: 0.9848
# Epoch 296/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0467 - accuracy: 0.9866
# Epoch 297/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0476 - accuracy: 0.9861
# Epoch 298/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0482 - accuracy: 0.9855
# Epoch 299/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0478 - accuracy: 0.9866
# Epoch 300/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0474 - accuracy: 0.9863
# Epoch 301/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0483 - accuracy: 0.9865
# Epoch 302/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0452 - accuracy: 0.9869
# Epoch 303/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0466 - accuracy: 0.9864
# Epoch 304/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0470 - accuracy: 0.9862
# Epoch 305/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0483 - accuracy: 0.9857
# Epoch 306/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0456 - accuracy: 0.9862
# Epoch 307/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0462 - accuracy: 0.9864
# Epoch 308/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0464 - accuracy: 0.9869
# Epoch 309/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0488 - accuracy: 0.9862
# Epoch 310/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0460 - accuracy: 0.9874
# Epoch 311/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0492 - accuracy: 0.9860
# Epoch 312/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0495 - accuracy: 0.9854
# Epoch 313/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0438 - accuracy: 0.9875
# Epoch 314/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0482 - accuracy: 0.9857
# Epoch 315/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0480 - accuracy: 0.9863
# Epoch 316/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0470 - accuracy: 0.9863
# Epoch 317/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0473 - accuracy: 0.9861
# Epoch 318/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0452 - accuracy: 0.9871
# Epoch 319/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0463 - accuracy: 0.9866
# Epoch 320/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0485 - accuracy: 0.9857
# Epoch 321/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0467 - accuracy: 0.9862
# Epoch 322/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0509 - accuracy: 0.9857
# Epoch 323/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0474 - accuracy: 0.9861
# Epoch 324/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0509 - accuracy: 0.9849
# Epoch 325/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0483 - accuracy: 0.9861
# Epoch 326/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0473 - accuracy: 0.9863
# Epoch 327/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0456 - accuracy: 0.9865
# Epoch 328/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0494 - accuracy: 0.9861
# Epoch 329/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0489 - accuracy: 0.9864
# Epoch 330/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0479 - accuracy: 0.9862
# Epoch 331/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0452 - accuracy: 0.9867
# Epoch 332/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0491 - accuracy: 0.9858
# Epoch 333/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0472 - accuracy: 0.9860
# Epoch 334/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0473 - accuracy: 0.9860
# Epoch 335/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0484 - accuracy: 0.9860
# Epoch 336/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0472 - accuracy: 0.9861
# Epoch 337/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0477 - accuracy: 0.9865
# Epoch 338/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0462 - accuracy: 0.9864
# Epoch 339/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0441 - accuracy: 0.9868
# Epoch 340/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0487 - accuracy: 0.9861
# Epoch 341/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0466 - accuracy: 0.9859
# Epoch 342/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0464 - accuracy: 0.9868
# Epoch 343/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0473 - accuracy: 0.9868
# Epoch 344/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0475 - accuracy: 0.9866
# Epoch 345/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0476 - accuracy: 0.9868
# Epoch 346/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0445 - accuracy: 0.9867
# Epoch 347/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0433 - accuracy: 0.9870
# Epoch 348/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0483 - accuracy: 0.9855
# Epoch 349/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0467 - accuracy: 0.9872
# Epoch 350/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0478 - accuracy: 0.9863
# Epoch 351/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0470 - accuracy: 0.9866
# Epoch 352/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0485 - accuracy: 0.9862
# Epoch 353/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0480 - accuracy: 0.9861
# Epoch 354/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0448 - accuracy: 0.9871
# Epoch 355/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0442 - accuracy: 0.9870
# Epoch 356/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0438 - accuracy: 0.9874
# Epoch 357/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0476 - accuracy: 0.9865
# Epoch 358/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0474 - accuracy: 0.9866
# Epoch 359/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0416 - accuracy: 0.9878
# Epoch 360/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0431 - accuracy: 0.9867
# Epoch 361/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0441 - accuracy: 0.9876
# Epoch 362/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0466 - accuracy: 0.9865
# Epoch 363/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0421 - accuracy: 0.9873
# Epoch 364/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0449 - accuracy: 0.9872
# Epoch 365/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0500 - accuracy: 0.9859
# Epoch 366/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0482 - accuracy: 0.9861
# Epoch 367/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0459 - accuracy: 0.9872
# Epoch 368/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0503 - accuracy: 0.9854
# Epoch 369/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0439 - accuracy: 0.9871
# Epoch 370/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0421 - accuracy: 0.9882
# Epoch 371/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0439 - accuracy: 0.9871
# Epoch 372/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0434 - accuracy: 0.9876
# Epoch 373/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0458 - accuracy: 0.9867
# Epoch 374/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0421 - accuracy: 0.9878
# Epoch 375/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0426 - accuracy: 0.9880
# Epoch 376/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0456 - accuracy: 0.9871
# Epoch 377/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0459 - accuracy: 0.9873
# Epoch 378/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0461 - accuracy: 0.9869
# Epoch 379/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0421 - accuracy: 0.9881
# Epoch 380/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0417 - accuracy: 0.9879
# Epoch 381/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0435 - accuracy: 0.9874
# Epoch 382/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0436 - accuracy: 0.9875
# Epoch 383/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0437 - accuracy: 0.9869
# Epoch 384/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0444 - accuracy: 0.9872
# Epoch 385/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0415 - accuracy: 0.9877
# Epoch 386/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0450 - accuracy: 0.9872
# Epoch 387/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0431 - accuracy: 0.9879
# Epoch 388/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0447 - accuracy: 0.9867
# Epoch 389/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0431 - accuracy: 0.9872
# Epoch 390/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0445 - accuracy: 0.9877
# Epoch 391/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0451 - accuracy: 0.9873
# Epoch 392/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0455 - accuracy: 0.9867
# Epoch 393/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0439 - accuracy: 0.9870
# Epoch 394/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0419 - accuracy: 0.9878
# Epoch 395/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0424 - accuracy: 0.9876
# Epoch 396/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0471 - accuracy: 0.9863
# Epoch 397/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0451 - accuracy: 0.9871
# Epoch 398/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0438 - accuracy: 0.9881
# Epoch 399/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0420 - accuracy: 0.9873
# Epoch 400/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0442 - accuracy: 0.9867
# Epoch 401/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0427 - accuracy: 0.9877
# Epoch 402/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0398 - accuracy: 0.9886
# Epoch 403/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0432 - accuracy: 0.9873
# Epoch 404/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0434 - accuracy: 0.9876
# Epoch 405/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0423 - accuracy: 0.9876
# Epoch 406/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0429 - accuracy: 0.9879
# Epoch 407/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0452 - accuracy: 0.9869
# Epoch 408/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0434 - accuracy: 0.9870
# Epoch 409/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0411 - accuracy: 0.9882
# Epoch 410/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0446 - accuracy: 0.9872
# Epoch 411/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0424 - accuracy: 0.9879
# Epoch 412/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0457 - accuracy: 0.9866
# Epoch 413/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0430 - accuracy: 0.9877
# Epoch 414/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0419 - accuracy: 0.9877
# Epoch 415/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0434 - accuracy: 0.9873
# Epoch 416/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0444 - accuracy: 0.9873
# Epoch 417/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0434 - accuracy: 0.9877
# Epoch 418/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0454 - accuracy: 0.9873
# Epoch 419/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0398 - accuracy: 0.9885
# Epoch 420/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0414 - accuracy: 0.9877
# Epoch 421/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0450 - accuracy: 0.9873
# Epoch 422/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0432 - accuracy: 0.9878
# Epoch 423/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0420 - accuracy: 0.9872
# Epoch 424/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0437 - accuracy: 0.9872
# Epoch 425/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0403 - accuracy: 0.9885
# Epoch 426/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0428 - accuracy: 0.9879
# Epoch 427/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0424 - accuracy: 0.9875
# Epoch 428/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0416 - accuracy: 0.9875
# Epoch 429/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0434 - accuracy: 0.9870
# Epoch 430/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0412 - accuracy: 0.9881
# Epoch 431/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0444 - accuracy: 0.9875
# Epoch 432/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0438 - accuracy: 0.9870
# Epoch 433/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0423 - accuracy: 0.9876
# Epoch 434/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0413 - accuracy: 0.9876
# Epoch 435/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0422 - accuracy: 0.9878
# Epoch 436/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0408 - accuracy: 0.9880
# Epoch 437/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0434 - accuracy: 0.9875
# Epoch 438/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0404 - accuracy: 0.9879
# Epoch 439/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0408 - accuracy: 0.9884
# Epoch 440/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0423 - accuracy: 0.9873
# Epoch 441/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0439 - accuracy: 0.9865
# Epoch 442/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0445 - accuracy: 0.9873
# Epoch 443/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0427 - accuracy: 0.9881
# Epoch 444/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0423 - accuracy: 0.9880
# Epoch 445/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0416 - accuracy: 0.9877
# Epoch 446/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0409 - accuracy: 0.9878
# Epoch 447/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0411 - accuracy: 0.9881
# Epoch 448/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0437 - accuracy: 0.9876
# Epoch 449/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0432 - accuracy: 0.9870
# Epoch 450/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0392 - accuracy: 0.9888
# Epoch 451/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0374 - accuracy: 0.9888
# Epoch 452/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0385 - accuracy: 0.9885
# Epoch 453/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0444 - accuracy: 0.9876
# Epoch 454/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0393 - accuracy: 0.9879
# Epoch 455/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0432 - accuracy: 0.9873
# Epoch 456/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0424 - accuracy: 0.9878
# Epoch 457/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0424 - accuracy: 0.9875
# Epoch 458/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0427 - accuracy: 0.9876
# Epoch 459/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0409 - accuracy: 0.9882
# Epoch 460/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0440 - accuracy: 0.9872
# Epoch 461/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0408 - accuracy: 0.9877
# Epoch 462/800
# ...
# Epoch 648/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0371 - accuracy: 0.9888
# Epoch 649/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0388 - accuracy: 0.9891
# Epoch 650/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0353 - accuracy: 0.9896
# Epoch 651/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0367 - accuracy: 0.9894
# Epoch 652/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0371 - accuracy: 0.9888
# Epoch 653/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0372 - accuracy: 0.9893
# Epoch 654/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0438 - accuracy: 0.9878
# Epoch 655/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0377 - accuracy: 0.9889
# Epoch 656/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0383 - accuracy: 0.9885
# Epoch 657/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0373 - accuracy: 0.9892
# Epoch 658/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0377 - accuracy: 0.9888
# Epoch 659/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0390 - accuracy: 0.9889
# Epoch 660/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0367 - accuracy: 0.9887
# Epoch 661/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0393 - accuracy: 0.9889
# Epoch 662/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0374 - accuracy: 0.9894
# Epoch 663/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0375 - accuracy: 0.9890
# Epoch 664/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0375 - accuracy: 0.9889
# Epoch 665/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0376 - accuracy: 0.9891
# Epoch 666/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0365 - accuracy: 0.9896
# Epoch 667/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0384 - accuracy: 0.9888
# Epoch 668/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0345 - accuracy: 0.9899
# Epoch 669/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0382 - accuracy: 0.9890
# Epoch 670/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0374 - accuracy: 0.9893
# Epoch 671/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0395 - accuracy: 0.9886
# Epoch 672/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0359 - accuracy: 0.9897
# Epoch 673/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0375 - accuracy: 0.9894
# Epoch 674/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0381 - accuracy: 0.9896
# Epoch 675/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0352 - accuracy: 0.9898
# Epoch 676/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0355 - accuracy: 0.9899
# Epoch 677/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0379 - accuracy: 0.9884
# Epoch 678/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0370 - accuracy: 0.9895
# Epoch 679/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0363 - accuracy: 0.9891
# Epoch 680/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0355 - accuracy: 0.9899
# Epoch 681/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0368 - accuracy: 0.9897
# Epoch 682/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0371 - accuracy: 0.9892
# Epoch 683/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0386 - accuracy: 0.9889
# Epoch 684/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0341 - accuracy: 0.9903
# Epoch 685/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0351 - accuracy: 0.9892
# Epoch 686/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0369 - accuracy: 0.9897
# Epoch 687/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0377 - accuracy: 0.9884
# Epoch 688/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0357 - accuracy: 0.9892
# Epoch 689/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0378 - accuracy: 0.9888
# Epoch 690/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0382 - accuracy: 0.9885
# Epoch 691/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0362 - accuracy: 0.9898
# Epoch 692/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0340 - accuracy: 0.9893
# Epoch 693/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0381 - accuracy: 0.9888
# Epoch 694/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0372 - accuracy: 0.9896
# Epoch 695/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0340 - accuracy: 0.9903
# Epoch 696/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0348 - accuracy: 0.9897
# Epoch 697/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0364 - accuracy: 0.9899
# Epoch 698/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0338 - accuracy: 0.9895
# Epoch 699/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0380 - accuracy: 0.9887
# Epoch 700/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0382 - accuracy: 0.9887
# Epoch 701/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0356 - accuracy: 0.9891
# Epoch 702/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0362 - accuracy: 0.9888
# Epoch 703/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0363 - accuracy: 0.9900
# Epoch 704/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0360 - accuracy: 0.9894
# Epoch 705/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0369 - accuracy: 0.9900
# Epoch 706/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0388 - accuracy: 0.9882
# Epoch 707/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0349 - accuracy: 0.9899
# Epoch 708/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0389 - accuracy: 0.9887
# Epoch 709/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0364 - accuracy: 0.9896
# Epoch 710/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0361 - accuracy: 0.9897
# Epoch 711/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0347 - accuracy: 0.9894
# Epoch 712/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0369 - accuracy: 0.9892
# Epoch 713/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0354 - accuracy: 0.9895
# Epoch 714/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0398 - accuracy: 0.9885
# Epoch 715/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0351 - accuracy: 0.9900
# Epoch 716/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0353 - accuracy: 0.9894
# Epoch 717/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0359 - accuracy: 0.9894
# Epoch 718/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0341 - accuracy: 0.9900
# Epoch 719/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0370 - accuracy: 0.9894
# Epoch 720/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0349 - accuracy: 0.9895
# Epoch 721/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0355 - accuracy: 0.9896
# Epoch 722/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0356 - accuracy: 0.9897
# Epoch 723/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0397 - accuracy: 0.9886
# Epoch 724/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0340 - accuracy: 0.9899
# Epoch 725/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0326 - accuracy: 0.9905
# Epoch 726/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0355 - accuracy: 0.9893
# Epoch 727/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0374 - accuracy: 0.9893
# Epoch 728/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0411 - accuracy: 0.9882
# Epoch 729/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0352 - accuracy: 0.9891
# Epoch 730/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0354 - accuracy: 0.9896
# Epoch 731/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0346 - accuracy: 0.9900
# Epoch 732/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0365 - accuracy: 0.9889
# Epoch 733/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0322 - accuracy: 0.9905
# Epoch 734/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0365 - accuracy: 0.9893
# Epoch 735/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0357 - accuracy: 0.9896
# Epoch 736/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0372 - accuracy: 0.9896
# Epoch 737/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0359 - accuracy: 0.9894
# Epoch 738/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0358 - accuracy: 0.9900
# Epoch 739/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0358 - accuracy: 0.9899
# Epoch 740/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0409 - accuracy: 0.9887
# Epoch 741/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0372 - accuracy: 0.9894
# Epoch 742/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0372 - accuracy: 0.9899
# Epoch 743/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0365 - accuracy: 0.9893
# Epoch 744/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0374 - accuracy: 0.9893
# Epoch 745/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0381 - accuracy: 0.9890
# Epoch 746/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0357 - accuracy: 0.9897
# Epoch 747/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0378 - accuracy: 0.9890
# Epoch 748/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0343 - accuracy: 0.9899
# Epoch 749/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0348 - accuracy: 0.9906
# Epoch 750/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0388 - accuracy: 0.9890
# Epoch 751/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0374 - accuracy: 0.9892
# Epoch 752/800
# 306/306 [==============================] - 9s 28ms/step - loss: 0.0365 - accuracy: 0.9891
# Epoch 753/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0352 - accuracy: 0.9899
# Epoch 754/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0345 - accuracy: 0.9898
# Epoch 755/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0400 - accuracy: 0.9889
# Epoch 756/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0346 - accuracy: 0.9897
# Epoch 757/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0337 - accuracy: 0.9905
# Epoch 758/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0384 - accuracy: 0.9893
# Epoch 759/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0356 - accuracy: 0.9898
# Epoch 760/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0363 - accuracy: 0.9896
# Epoch 761/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0344 - accuracy: 0.9903
# Epoch 762/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0337 - accuracy: 0.9900
# Epoch 763/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0353 - accuracy: 0.9899
# Epoch 764/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0340 - accuracy: 0.9901
# Epoch 765/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0376 - accuracy: 0.9890
# Epoch 766/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0354 - accuracy: 0.9893
# Epoch 767/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0355 - accuracy: 0.9897
# Epoch 768/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0376 - accuracy: 0.9897
# Epoch 769/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0349 - accuracy: 0.9898
# Epoch 770/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0343 - accuracy: 0.9897
# Epoch 771/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0333 - accuracy: 0.9900
# Epoch 772/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0350 - accuracy: 0.9899
# Epoch 773/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0360 - accuracy: 0.9891
# Epoch 774/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0369 - accuracy: 0.9894
# Epoch 775/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0344 - accuracy: 0.9899
# Epoch 776/800
# 306/306 [==============================] - 8s 28ms/step - loss: 0.0362 - accuracy: 0.9895
# Epoch 777/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0345 - accuracy: 0.9897
# Epoch 778/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0350 - accuracy: 0.9893
# Epoch 779/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0338 - accuracy: 0.9908
# Epoch 780/800
# 306/306 [==============================] - 8s 25ms/step - loss: 0.0359 - accuracy: 0.9891
# Epoch 781/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0370 - accuracy: 0.9896
# Epoch 782/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0321 - accuracy: 0.9905
# Epoch 783/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0332 - accuracy: 0.9907
# Epoch 784/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0321 - accuracy: 0.9907
# Epoch 785/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0369 - accuracy: 0.9893
# Epoch 786/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0367 - accuracy: 0.9896
# Epoch 787/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0358 - accuracy: 0.9901
# Epoch 788/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0366 - accuracy: 0.9894
# Epoch 789/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0346 - accuracy: 0.9902
# Epoch 790/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0358 - accuracy: 0.9900
# Epoch 791/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0356 - accuracy: 0.9896
# Epoch 792/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0359 - accuracy: 0.9901
# Epoch 793/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0339 - accuracy: 0.9903
# Epoch 794/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0361 - accuracy: 0.9894
# Epoch 795/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0369 - accuracy: 0.9893
# Epoch 796/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0357 - accuracy: 0.9894
# Epoch 797/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0364 - accuracy: 0.9892
# Epoch 798/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0387 - accuracy: 0.9887
# Epoch 799/800
# 306/306 [==============================] - 8s 26ms/step - loss: 0.0342 - accuracy: 0.9900
# Epoch 800/800
# 306/306 [==============================] - 8s 27ms/step - loss: 0.0346 - accuracy: 0.9901
# Training took 110.82704569498698 minutes.

# %% [markdown]
# Let's evaluate the model:

# %%
eval_train_ds = prepare_for_evaluation(labeled_ds_train)
eval_test_ds = prepare_for_evaluation(labeled_ds_test)
train_results = model.evaluate(eval_train_ds)
print('Train loss, train acc:', train_results)
test_results = model.evaluate(eval_test_ds)
print('Test loss, test acc:', test_results)

train_acc = train_results[1]
test_acc = test_results[1]
experiment.log_metric("Train accuracy", train_acc)
experiment.log_metric("Test accuracy", test_acc)
# Out:
# 307/307 [==============================] - 20s 66ms/step - loss: 5.0716e-04 - accuracy: 0.9999
# Train loss, train acc: [0.0005071615451015532, 0.9999489784240723]
# 99/99 [==============================] - 7s 68ms/step - loss: 0.0303 - accuracy: 0.9918
# Test loss, test acc: [0.03031258098781109, 0.9918448328971863]

# %% [markdown]
# There are lot of ways to improve the model above. According to Stallkamp et al. (2012), an ensemble of CNNs can reach 99.46%. Good human performance is
# 99.22%.

# %%
Experiment.end(experiment)
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/lallakala/hw2-version0/0f4cfb7b424144e9a5e99aa250717745
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     Test accuracy          : 0.9918448328971863
# COMET INFO:     Train accuracy         : 0.9999489784240723
# COMET INFO:     accuracy [800]         : (0.3740553557872772, 0.9907832741737366)
# COMET INFO:     batch_accuracy [24800] : (0.03125, 1.0)
# COMET INFO:     batch_loss [24800]     : (0.0004166844591964036, 5.34185266494751)
# COMET INFO:     epoch_duration [800]   : (7.8053157219983405, 27.835897076998663)
# COMET INFO:     loss [800]             : (0.03205980360507965, 2.289971351623535)
# COMET INFO:   Others:
# COMET INFO:     random seed      : 420420
# COMET INFO:     trainable_params : 133995
# COMET INFO:   Parameters:
# COMET INFO:     Adam_amsgrad       : 1
# COMET INFO:     Adam_beta_1        : 0.9
# COMET INFO:     Adam_beta_2        : 0.999
# COMET INFO:     Adam_decay         : 1
# COMET INFO:     Adam_epsilon       : 0.1
# COMET INFO:     Adam_learning_rate : 0.05
# COMET INFO:     Adam_name          : Adam
# COMET INFO:     Optimizer          : Adam
# COMET INFO:     epochs             : 800
# COMET INFO:     steps              : 306
# COMET INFO:   Uploads [count]:
# COMET INFO:     code                : 1 (9 KB)
# COMET INFO:     environment details : 1
# COMET INFO:     filename [2]        : 2
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading stats to Comet before program termination (may take several seconds)
